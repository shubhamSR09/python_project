# %%
from tkinter import*
import datetime 
import time 
import winsound

# %%
def st_alarm(set_alarm_time):
    while True:
        time.sleep(1)
        current_time = datetime.datetime.now()
        now=current_time.strftime("%H:%M:%S")
        date=current_time.strftime("%d/%m/%Y")
        print("The set Date is",date)
        print(now)
        if now == set_alarm_time:
            print("Come ON!!!")
            winsound.PlaySound("alarm.wav",winsound.SND_ASYNC)
            break
            
    
def actual_time():
    alarm_timer = f"{hour.get()}:{minut.get()}:{sec.get()}"
    st_alarm(alarm_timer)
    
    
clock = Tk()
clock.title("Shubham's Alarm clock")
clock.geometry('400x300')
time_format = Label(clock,text = "Enter Time in 24 Hour Format",fg='green',bg='black',font='Arial').place(x=90,y=120)
addTime = Label(clock,text="Hour Minute Second",font=60).place(x=110)
set_alarm = Label(clock,text ="When You Want the alram",fg='blue',relief='solid').place(x=0,y=50)

hour = StringVar()
minut = StringVar()
sec = StringVar()

hourTime = Entry(clock,textvariable = hour,bg = "red", width=15).place(x=110,y=30)
minTime = Entry(clock,textvariable = minut,bg = "red", width=15).place(x=160,y=30)
secTime = Entry(clock,textvariable = sec,bg = "red", width=15).place(x=210,y=30)

submit = Button(clock,text ="Create Alarm",fg ="blue",width =10,command=actual_time).place(x=110,y=80)
clock.mainloop()
# Out:
# The set Date is 14/04/2022
# 18:16:19
# The set Date is 14/04/2022
# 18:16:20
# The set Date is 14/04/2022
# 18:16:21
# The set Date is 14/04/2022
# 18:16:22
# The set Date is 14/04/2022
# 18:16:23
# The set Date is 14/04/2022
# 18:16:24
# The set Date is 14/04/2022
# 18:16:25
# The set Date is 14/04/2022
# 18:16:26
# The set Date is 14/04/2022
# 18:16:27
# The set Date is 14/04/2022
# 18:16:28
# The set Date is 14/04/2022
# 18:16:29
# The set Date is 14/04/2022
# 18:16:30
# The set Date is 14/04/2022
# 18:16:31
# The set Date is 14/04/2022
# 18:16:32
# The set Date is 14/04/2022
# 18:16:33
# The set Date is 14/04/2022
# 18:16:34
# The set Date is 14/04/2022
# 18:16:36
# The set Date is 14/04/2022
# 18:16:37
# The set Date is 14/04/2022
# 18:16:38
# The set Date is 14/04/2022
# 18:16:39
# The set Date is 14/04/2022
# 18:16:40
# The set Date is 14/04/2022
# 18:16:41
# The set Date is 14/04/2022
# 18:16:42
# The set Date is 14/04/2022
# 18:16:43
# The set Date is 14/04/2022
# 18:16:44
# The set Date is 14/04/2022
# 18:16:45
# The set Date is 14/04/2022
# 18:16:46
# The set Date is 14/04/2022
# 18:16:47
# The set Date is 14/04/2022
# 18:16:48
# The set Date is 14/04/2022
# 18:16:49
# The set Date is 14/04/2022
# 18:16:50
# The set Date is 14/04/2022
# 18:16:51
# The set Date is 14/04/2022
# 18:16:52
# The set Date is 14/04/2022
# 18:16:53
# The set Date is 14/04/2022
# 18:16:54
# The set Date is 14/04/2022
# 18:16:55
# The set Date is 14/04/2022
# 18:16:56
# The set Date is 14/04/2022
# 18:16:57
# The set Date is 14/04/2022
# 18:16:58

# %%
+++
